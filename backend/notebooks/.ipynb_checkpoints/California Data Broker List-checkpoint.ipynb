# %%
import pandas as pd
from io import StringIO
import requests


#CALIFORNIA_LIST_URL = "https://www.oag.ca.gov/data-brokers/export?download=1&eid=4362&token=xMURLGqtwqmb0B2gcssOaxYU6uIAnNyegsydSeusXlg"
CALIFORNIA_LIST_PATH = "../data/data-brokers-california.csv"

#request = requests.get(CALIFORNIA_LIST_URL)
#data = request.content.decode('utf-8')
#cali_df = pd.read_csv(StringIO(data), index_col=0 , thousands=',')

cali_df = pd.read_csv(CALIFORNIA_LIST_PATH, index_col=0, parse_dates=['Date Added'], thousands=',')
cali_df.tail(1)
# Out:
#                  Email Address (Accessible to the public)  \
# Data Broker Name
# The Data Group           compliance [at] thedatagroup.com
#
#                               Website URL  \
# Data Broker Name
# The Data Group    http://TheDataGroup.com
#
#                                                    Physical Address  \
# Data Broker Name
# The Data Group    3280 East Colonial DriveOrlando, FL 32803Unite...
#
#                  How a consumer may opt out of sale or submit requests under the CCPA  \
# Data Broker Name
# The Data Group    A consumer may submit opt-out requests by emai...
#
#                  How a protected individual can demand deletion of information posted online under Gov. Code sections 6208.1(b) or 6254.21(c)(1)  \
# Data Broker Name
# The Data Group    The Data Group does not post data online; howe...
#
#                  Additional information about data collecting practices  \
# Data Broker Name
# The Data Group                                                  NaN
#
#                  Date Added
# Data Broker Name
# The Data Group   2020-07-22

# %%
cali_df['Email'] =  cali_df.apply(lambda row: row['Email Address (Accessible to the public)'].replace(" [at] ", "@") , axis = 1) 
cali_df
# Out:
#                                                    Email Address (Accessible to the public)  \
# Data Broker Name
# Allant Group, LLC                                              privacy [at] allantgroup.com
# Exponential Interactive, Inc. doing business as...                      privacy [at] VDX.tv
# Infocore, Inc.                                                       info [at] infocore.com
# LO-EmailListcom LLC                                               JayDunsing [at] gmail.com
# Consumerbase LLC/DBA Exact Data                             rob.sullivan [at] exactdata.com
# ...                                                                                     ...
# Semcasting, Inc.                                          privacychoice [at] semcasting.com
# Fyllo                                                           privacy [at] hellofyllo.com
# Tandem Marketing, LLC                                       info [at] tandemmarketingnv.com
# Civis Analytics, Inc.                                dataprotection [at] civisanalytics.com
# The Data Group                                             compliance [at] thedatagroup.com
#
#                                                                            Website URL  \
# Data Broker Name
# Allant Group, LLC                                          http://www.allantgroup.com/
# Exponential Interactive, Inc. doing business as...                       http://vdx.tv
# Infocore, Inc.                                                 http://www.infocore.com
# LO-EmailListcom LLC                                  http://loanofficercontactinfo.com
# Consumerbase LLC/DBA Exact Data                               http://www.exactdata.com
# ...                                                                                ...
# Semcasting, Inc.                                             http://www.semcasting.com
# Fyllo                                                        http://www.hellofyllo.com
# Tandem Marketing, LLC                               https://www.fhamortgagefinder.com/
# Civis Analytics, Inc.                                  https://www.civisanalytics.com/
# The Data Group                                                 http://TheDataGroup.com
#
#                                                                                      Physical Address  \
# Data Broker Name
# Allant Group, LLC                                   2655 Warrenville RdSuite 200Downers Grover, IL...
# Exponential Interactive, Inc. doing business as...  5858 Horton StreetSuite 300Emeryville, CA 9413...
# Infocore, Inc.                                       2766 Gateway RoadCarlsbad, CA 92009United States
# LO-EmailListcom LLC                                 7200 East Ashling LaneTucson, AZ 85715United S...
# Consumerbase LLC/DBA Exact Data                     33 N. Dearborn DriveSuite 200Chicago, IL 60602...
# ...                                                                                               ...
# Semcasting, Inc.                                    41 High StreetNorth Andover, MA 01845United St...
# Fyllo                                               845 W. Washington Boulevard3rd floorChicago, I...
# Tandem Marketing, LLC                               1550 W Horizon Ridge Pkwy R Suite #R 610Hender...
# Civis Analytics, Inc.                               200 W Monroe StSTE 2200Chicago, IL 60606United...
# The Data Group                                      3280 East Colonial DriveOrlando, FL 32803Unite...
#
#                                                    How a consumer may opt out of sale or submit requests under the CCPA  \
# Data Broker Name
# Allant Group, LLC                                   Notify Allant Group, LLC using instructions in...
# Exponential Interactive, Inc. doing business as...  7.\tCONTACT INFORMATION\r\n\r\nPlease contact ...
# Infocore, Inc.                                                                   contact the company
# LO-EmailListcom LLC                                 Fill out a form on my website or simply send a...
# Consumerbase LLC/DBA Exact Data                     Through a link on our website as well as at ou...
# ...                                                                                               ...
# Semcasting, Inc.                                    Semcasting respects your control over your inf...
# Fyllo                                               Our privacy policy provides users the ability ...
# Tandem Marketing, LLC                               Web form (sent to info@tandemmarketing.com), b...
# Civis Analytics, Inc.                               If you are a California resident and would lik...
# The Data Group                                      A consumer may submit opt-out requests by emai...
#
#                                                    How a protected individual can demand deletion of information posted online under Gov. Code sections 6208.1(b) or 6254.21(c)(1)  \
# Data Broker Name
# Allant Group, LLC                                   Notify Allant Group, LLC using instructions in...
# Exponential Interactive, Inc. doing business as...  7.\tCONTACT INFORMATION\r\n\r\nPlease contact ...
# Infocore, Inc.                                                                    contact the company
# LO-EmailListcom LLC                                 Fill out a form on my website or simply send a...
# Consumerbase LLC/DBA Exact Data                     Through a link on our website as well as at ou...
# ...                                                                                               ...
# Semcasting, Inc.                                    See Semcasting's Privacy Policy at https://www...
# Fyllo                                               Our privacy policy enables a user to request t...
# Tandem Marketing, LLC                               Web form (sent to info@tandemmarketing.com), b...
# Civis Analytics, Inc.                               If you are a California resident and would lik...
# The Data Group                                      The Data Group does not post data online; howe...
#
#                                                    Additional information about data collecting practices  \
# Data Broker Name
# Allant Group, LLC                                   Allant does not collect consumer data directly...
# Exponential Interactive, Inc. doing business as...                                               N/A.
# Infocore, Inc.                                                                                    NaN
# LO-EmailListcom LLC                                                                               NaN
# Consumerbase LLC/DBA Exact Data                                                                   NaN
# ...                                                                                               ...
# Semcasting, Inc.                                    See Semcasting's Privacy Policy at https://www...
# Fyllo                                               Fyllo collects information in three ways: info...
# Tandem Marketing, LLC                                                                             NaN
# Civis Analytics, Inc.                                  https://www.civisanalytics.com/privacy_policy/
# The Data Group                                                                                    NaN
#
#                                                    Date Added  \
# Data Broker Name
# Allant Group, LLC                                  2020-01-29
# Exponential Interactive, Inc. doing business as... 2020-01-29
# Infocore, Inc.                                     2020-01-16
# LO-EmailListcom LLC                                2020-01-16
# Consumerbase LLC/DBA Exact Data                    2020-01-14
# ...                                                       ...
# Semcasting, Inc.                                   2020-07-22
# Fyllo                                              2020-07-14
# Tandem Marketing, LLC                              2020-07-22
# Civis Analytics, Inc.                              2020-07-27
# The Data Group                                     2020-07-22
#
#                                                                                 Email
# Data Broker Name
# Allant Group, LLC                                             privacy@allantgroup.com
# Exponential Interactive, Inc. doing business as...                     privacy@VDX.tv
# Infocore, Inc.                                                      info@infocore.com
# LO-EmailListcom LLC                                              JayDunsing@gmail.com
# Consumerbase LLC/DBA Exact Data                            rob.sullivan@exactdata.com
# ...                                                                               ...
# Semcasting, Inc.                                         privacychoice@semcasting.com
# Fyllo                                                          privacy@hellofyllo.com
# Tandem Marketing, LLC                                      info@tandemmarketingnv.com
# Civis Analytics, Inc.                               dataprotection@civisanalytics.com
# The Data Group                                            compliance@thedatagroup.com
#
# [362 rows x 8 columns]

# %%
from tld import get_tld

cali_df['Domain'] =  cali_df.apply(lambda row: get_tld(row['Website URL']).fld) , axis = 1) 
cali_df
